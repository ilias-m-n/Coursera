# %% [markdown]
# # Monte Carlo simulation of Dynamic Risk Budgeting between PSP and GHP
#
# We've looked at the fundamental problem of how much to allocate in the safe asset vs the performance seeking asset, and we investigated static and glidepath based techniques. Now we'll look at modern dynamic techniques that are inspired by CPPI to ensure that the account value reaches a certain target minimum floor, but also maintains exposure to the upside through a dynamic risk budget

# %%
import numpy as np
import pandas as pd
import kits.asset_mgmt_kit as amk
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# Let's start by building 500 scenarios for interest rates, an duration matched bond portfolio (proxied by a zero coupon bond) and a stock portfolio.

# %%
n_scenarios =  5000
rates, zc_prices = amk.cir(10, n_scenarios=n_scenarios, b=0.03, r_0 = 0.03, sigma=0.02)
price_eq = amk.gbm(n_years=10,n_scenarios=n_scenarios, mu=0.07, sigma=0.15)
rets_eq = price_eq.pct_change().dropna()
rets_zc = zc_prices.pct_change().dropna()
rets_7030b = amk.bt_mix(rets_eq, rets_zc, allocator=amk.fixedmix_allocator, w1=0.7)
pd.concat([amk.terminal_stats(rets_zc, name="ZC", floor=0.75), 
           amk.terminal_stats(rets_eq, name="Eq", floor=0.75),
           amk.terminal_stats(rets_7030b, name="70/30", floor=0.75)],
          axis=1).round(2)
# Out:
#              ZC    Eq  70/30
# mean       1.34  1.96   1.75
# std        0.00  0.97   0.59
# p_breach    NaN  0.04   0.01
# e_short     NaN  0.11   0.08
# p_reach     NaN   NaN    NaN
# e_surplus   NaN   NaN    NaN

# %% [markdown]
# Let's write a new allocator that we'll call a Floor Allocator applies a dynamic risk budget to allocate more to the PSP when there is a cushion, similar to what we did for CPPI
#
# ```python
# def floor_allocator(psp_r, ghp_r, floor, zc_prices, m=3):
#     """
#     Allocate between PSP and GHP with the goal to provide exposure to the upside
#     of the PSP without going violating the floor.
#     Uses a CPPI-style dynamic risk budgeting algorithm by investing a multiple
#     of the cushion in the PSP
#     Returns a DataFrame with the same shape as the psp/ghp representing the weights in the PSP
#     """
#     if zc_prices.shape != psp_r.shape:
#         raise ValueError("PSP and ZC Prices must have the same shape")
#     n_steps, n_scenarios = psp_r.shape
#     account_value = np.repeat(1, n_scenarios)
#     floor_value = np.repeat(1, n_scenarios)
#     w_history = pd.DataFrame(index=psp_r.index, columns=psp_r.columns)
#     for step in range(n_steps):
#         floor_value = floor*zc_prices.iloc[step] ## PV of Floor assuming today's rates and flat YC
#         cushion = (account_value - floor_value)/account_value
#         psp_w = (m*cushion).clip(0, 1) # same as applying min and max
#         ghp_w = 1-psp_w
#         psp_alloc = account_value*psp_w
#         ghp_alloc = account_value*ghp_w
#         # recompute the new account value at the end of this step
#         account_value = psp_alloc*(1+psp_r.iloc[step]) + ghp_alloc*(1+ghp_r.iloc[step])
#         w_history.iloc[step] = psp_w
#     return w_history
# ```

# %%
rets_floor75 = amk.bt_mix(rets_eq, rets_zc, allocator=amk.floor_allocator, floor=.75,  zc_prices=zc_prices[1:])
pd.concat([amk.terminal_stats(rets_zc, name="ZC", floor=0.75), 
           amk.terminal_stats(rets_eq, name="Eq", floor=0.75),
           amk.terminal_stats(rets_7030b, name="70/30", floor=0.75),
           amk.terminal_stats(rets_floor75, name="Floor75", floor=0.75),
          ],
          axis=1).round(2)
# Out:
#              ZC    Eq  70/30  Floor75
# mean       1.34  1.96   1.75     1.94
# std        0.00  0.97   0.59     0.98
# p_breach    NaN  0.04   0.01      NaN
# e_short     NaN  0.11   0.08      NaN
# p_reach     NaN   NaN    NaN      NaN
# e_surplus   NaN   NaN    NaN      NaN

# %%
rets_floor75m1 = amk.bt_mix(rets_eq, rets_zc, allocator=amk.floor_allocator, zc_prices=zc_prices[1:], floor=.75, m=1)
pd.concat([amk.terminal_stats(rets_zc, name="ZC", floor=0.75), 
           amk.terminal_stats(rets_eq, name="Eq", floor=0.75),
           amk.terminal_stats(rets_7030b, name="70/30", floor=0.75),
           amk.terminal_stats(rets_floor75, name="Floor75", floor=0.75),
           amk.terminal_stats(rets_floor75m1, name="Floor75m1", floor=0.75),
          ],
          axis=1).round(2)
# Out:
#              ZC    Eq  70/30  Floor75  Floor75m1
# mean       1.34  1.96   1.75     1.94       1.62
# std        0.00  0.97   0.59     0.98       0.43
# p_breach    NaN  0.04   0.01      NaN        NaN
# e_short     NaN  0.11   0.08      NaN        NaN
# p_reach     NaN   NaN    NaN      NaN        NaN
# e_surplus   NaN   NaN    NaN      NaN        NaN

# %%
rets_floor75m5 = amk.bt_mix(rets_eq, rets_zc, allocator=amk.floor_allocator, zc_prices=zc_prices[1:], floor=.75, m=5)
rets_floor75m10 = amk.bt_mix(rets_eq, rets_zc, allocator=amk.floor_allocator, zc_prices=zc_prices[1:], floor=.75, m=10)
pd.concat([amk.terminal_stats(rets_zc, name="ZC", floor=0.75), 
           amk.terminal_stats(rets_eq, name="Eq", floor=0.75),
           amk.terminal_stats(rets_7030b, name="70/30", floor=0.75),
           amk.terminal_stats(rets_floor75, name="Floor75m3", floor=0.75),
           amk.terminal_stats(rets_floor75m1, name="Floor75m1", floor=0.75),
           amk.terminal_stats(rets_floor75m5, name="Floor75m5", floor=0.75),
           amk.terminal_stats(rets_floor75m10, name="Floor75m10", floor=0.75)
          ],
          axis=1).round(2)
# Out:
#              ZC    Eq  70/30  Floor75m3  Floor75m1  Floor75m5  Floor75m10
# mean       1.34  1.96   1.75       1.94       1.62       1.95        1.95
# std        0.00  0.97   0.59       0.98       0.43       0.98        0.98
# p_breach    NaN  0.04   0.01        NaN        NaN        NaN        0.03
# e_short     NaN  0.11   0.08        NaN        NaN        NaN        0.00
# p_reach     NaN   NaN    NaN        NaN        NaN        NaN         NaN
# e_surplus   NaN   NaN    NaN        NaN        NaN        NaN         NaN

# %%
tv_eq = amk.terminal_values(rets_eq)
tv_zc = amk.terminal_values(rets_zc)
tv_7030b = amk.terminal_values(rets_7030b)
tv_floor75 = amk.terminal_values(rets_floor75)
tv_floor75m1 = amk.terminal_values(rets_floor75m1)
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 6))
sns.distplot(tv_eq, color="red", label="100% Equities", bins=100)
#sns.distplot(tv_zc, color="blue", label="100% Immunized Bonds")
sns.distplot(tv_7030b, color="orange", label="70/30 Equities/Bonds", bins=100)
sns.distplot(tv_floor75, color="green", label="Floor at 75%", bins=100)

plt.legend();
# Out:
# C:\Users\ilias\AppData\Local\Temp/ipykernel_11440/1170880004.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tv_eq, color="red", label="100% Equities", bins=100)
# C:\Users\ilias\AppData\Local\Temp/ipykernel_11440/1170880004.py:11: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
# ...

# %%
tv_eq = amk.terminal_values(rets_eq)
tv_zc = amk.terminal_values(rets_zc)
tv_7030b = amk.terminal_values(rets_7030b)
tv_floor75 = amk.terminal_values(rets_floor75)
tv_floor75m1 = amk.terminal_values(rets_floor75m1)
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 6))
sns.distplot(tv_eq, color="red", label="100% Equities", bins=100)
plt.axvline(tv_eq.mean(), ls="--", color="red")
#sns.distplot(tv_zc, color="blue", label="100% Immunized Bonds")
#plt.axvline(tv_zc.mean(), ls="--", color="blue")
sns.distplot(tv_7030b, color="orange", label="70/30 Equities/Bonds", bins=100)
plt.axvline(tv_7030b.mean(), ls="--", color="orange")
sns.distplot(tv_floor75, color="green", label="Floor at 75%", bins=100)
plt.axvline(tv_floor75.mean(), ls="--", color="green")

plt.legend();
# Out:
# C:\Users\ilias\AppData\Local\Temp/ipykernel_11440/1581048081.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tv_eq, color="red", label="100% Equities", bins=100)
# C:\Users\ilias\AppData\Local\Temp/ipykernel_11440/1581048081.py:13: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
# ...

# %% [markdown]
# ## Dynamic Risk Budgeting with Drawdown instead of a fixed floor

# %% [markdown]
# ```python
# def drawdown_allocator(psp_r, ghp_r, maxdd, m=3):
#     """
#     Allocate between PSP and GHP with the goal to provide exposure to the upside
#     of the PSP without going violating the floor.
#     Uses a CPPI-style dynamic risk budgeting algorithm by investing a multiple
#     of the cushion in the PSP
#     Returns a DataFrame with the same shape as the psp/ghp representing the weights in the PSP
#     """
#     n_steps, n_scenarios = psp_r.shape
#     account_value = np.repeat(1, n_scenarios)
#     floor_value = np.repeat(1, n_scenarios)
#     ### For MaxDD
#     peak_value = np.repeat(1, n_scenarios)
#     w_history = pd.DataFrame(index=psp_r.index, columns=psp_r.columns)
#     for step in range(n_steps):
#         ### For MaxDD
#         floor_value = (1-maxdd)*peak_value ### Floor is based on Prev Peak
#         cushion = (account_value - floor_value)/account_value
#         psp_w = (m*cushion).clip(0, 1) # same as applying min and max
#         ghp_w = 1-psp_w
#         psp_alloc = account_value*psp_w
#         ghp_alloc = account_value*ghp_w
#         # recompute the new account value at the end of this step
#         account_value = psp_alloc*(1+psp_r.iloc[step]) + ghp_alloc*(1+ghp_r.iloc[step])
#         ### For MaxDD
#         peak_value = np.maximum(peak_value, account_value) ### For MaxDD
#         w_history.iloc[step] = psp_w
#     return w_history
# ```

# %%
cashrate = 0.02
monthly_cashreturn = (1+cashrate)**(1/12) - 1
rets_cash = pd.DataFrame(data= monthly_cashreturn, index=rets_eq.index, columns=rets_eq.columns)
rets_maxdd25 = amk.bt_mix(rets_eq, rets_cash, allocator=amk.drawdown_allocator, maxdd=.25)
tv_maxdd25 = amk.terminal_values(rets_maxdd25)
pd.concat([amk.terminal_stats(rets_zc, name="ZC", floor=0.75), 
           amk.terminal_stats(rets_eq, name="Eq", floor=0.75),
           amk.terminal_stats(rets_7030b, name="70/30", floor=0.75),
           amk.terminal_stats(rets_floor75, name="Floor75", floor=0.75),
           amk.terminal_stats(rets_floor75m1, name="Floor75m1", floor=0.75),
           amk.terminal_stats(rets_floor75m5, name="Floor75m5", floor=0.75),
           amk.terminal_stats(rets_floor75m10, name="Floor75m10", floor=0.75),
           amk.terminal_stats(rets_maxdd25, name="MaxDD25", floor=0.75)           
          ],
          axis=1).round(2)
# Out:
#              ZC    Eq  70/30  Floor75  Floor75m1  Floor75m5  Floor75m10  \
# mean       1.34  1.96   1.75     1.94       1.62       1.95        1.95
# std        0.00  0.97   0.59     0.98       0.43       0.98        0.98
# p_breach    NaN  0.04   0.01      NaN        NaN        NaN        0.03
# e_short     NaN  0.11   0.08      NaN        NaN        NaN        0.00
# p_reach     NaN   NaN    NaN      NaN        NaN        NaN         NaN
# e_surplus   NaN   NaN    NaN      NaN        NaN        NaN         NaN
#
#            MaxDD25
# mean          1.62
# std           0.54
# p_breach       NaN
# e_short        NaN
# p_reach        NaN
# e_surplus      NaN

# %%
amk.summary_stats(rets_maxdd25)["Max Drawdown"].min()
# Out:
# -0.23448128392926654

# %%
# Plot
plt.figure(figsize=(12, 6))
sns.distplot(tv_eq, color="red", label="100% Equities", bins=100)
plt.axvline(tv_eq.mean(), ls="--", color="red")
#sns.distplot(tv_zc, color="blue", label="100% Immunized Bonds")
#plt.axvline(tv_zc.mean(), ls="--", color="blue")
sns.distplot(tv_7030b, color="orange", label="70/30 Equities/Bonds", bins=100)
plt.axvline(tv_7030b.mean(), ls="--", color="orange")
sns.distplot(tv_floor75, color="green", label="Floor at 75%", bins=100)
plt.axvline(tv_floor75.mean(), ls="--", color="green")
sns.distplot(tv_maxdd25, color="yellow", label="MaxDD = 25%", bins=100)
plt.axvline(tv_maxdd25.mean(), ls="--", color="yellow")
plt.legend();
# Out:
# C:\Users\ilias\AppData\Local\Temp/ipykernel_11440/4051065936.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tv_eq, color="red", label="100% Equities", bins=100)
# C:\Users\ilias\AppData\Local\Temp/ipykernel_11440/4051065936.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %% [markdown]
# ## Backtesting Dynamic Strategies with Historical Data
#
# Try and work with real historic data such as a the Industry Portfolios or the Total Market Index we constructed and run back tests with different parameter values. For instance:

# %%
rets_tmi =  amk.get_total_market_index_returns()["1990":]
dd_tmi = amk.drawdown(rets_tmi)
ax = dd_tmi["Wealth"].plot(figsize=(12,6), ls="-", color="goldenrod")
dd_tmi["Previous Peak"].plot(ax=ax, ls=":", color="goldenrod")

# %%
cashrate = 0.03
monthly_cashreturn = (1+cashrate)**(1/12) - 1
rets_cash = pd.DataFrame(data= monthly_cashreturn, index=rets_tmi.index, columns=[0]) # 1 column dataframe
rets_maxdd25 = amk.bt_mix(pd.DataFrame(rets_tmi), rets_cash, allocator=amk.drawdown_allocator, maxdd=.25, m=5)
dd_25 = amk.drawdown(rets_maxdd25[0])

ax = dd_tmi["Wealth"].plot(figsize=(12,6), ls="-", color="goldenrod", label="Market", legend=True)
dd_tmi["Previous Peak"].plot(ax=ax, ls=":", color="goldenrod")
dd_25["Wealth"].plot(ax=ax, label="MaxDD 25%", color="cornflowerblue", legend=True)
dd_25["Previous Peak"].plot(ax=ax, color="cornflowerblue", ls=":")

# %%
amk.summary_stats(pd.concat([rets_tmi.rename("Market"), rets_maxdd25[0].rename("MaxDD")], axis=1))
# Out:
#         Annualized Return  Annualized Vol  Skewness  Kurtosis  \
# Market           0.096058        0.145419 -0.668827  4.247282
# MaxDD            0.090062        0.112755 -0.630463  5.015334
#
#         Cornish-Fisher VaR (5%)  Historic CVaR (5%)  Sharpe Ratio  \
# Market                 0.066949            0.094633      0.441951
# MaxDD                  0.049978            0.071074      0.518327
#
#         Max Drawdown
# Market     -0.499943
# MaxDD      -0.244212
